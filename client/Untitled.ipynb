# %%
# %run main.py
# Out:
# C:\Users\user\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# Geochemistry Py - User Behaviour Testing Demo
# ....... Initializing .......
# -*-*- Data Uploaded -*-*-
# Data Option:
# 1 - Own Data
# 2 - Testing Data (Built-in)
# (User) ➜ @Number:  2
# Testing Data Option:
# 1 - Mantle vs Crust Data
# 2 - Data For Provanace Classification
# 3 - Data For Metamorphic Group
# (User) ➜ @Number:  2
# --------------------
# Index - Column Name
# 1 - composition
# 2 - author
# 3 - journal
# 4 - region
# 5 - sample name
# 6 - host-rock_type/metamorphic_facies
# 7 - lithology/protolith
# 8 - P(kbar)
# 9 - T(°C)
# 10 - SiO2
# 11 - TiO2
# 12 - Al2O3
# 13 - Cr2O3
# 14 - FeOtotal
# 15 - MnO
# 16 - MgO
# 17 - CaO
# --------------------
# (Press Enter key to move forward.)
# ...
